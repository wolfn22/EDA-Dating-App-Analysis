# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the dataset

df = pd.read_csv('clean_1.csv')

# %%
df.head()
# Out:
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
# 3   23     single   m    straight            thin         vegetarian
# 4   29     single   m    straight        athletic                NaN
#
#      drinks      drugs                          education  \
# 0  socially      never      working on college/university
# 1     often  sometimes              working on space camp
# 2  socially        NaN     graduated from masters program
# 3  socially        NaN      working on college/university
# 4  socially      never  graduated from college/university
#
#              ethnicity  height  income                          job  \
# 0         asian, white    75.0      -1               transportation
# ...

# %%
df.tail()
# Out:
#        age  status sex orientation body_type             diet      drinks  \
# 59941   59  single   f    straight       NaN              NaN    socially
# 59942   24  single   m    straight       fit  mostly anything       often
# 59943   42  single   m    straight   average  mostly anything  not at all
# 59944   27  single   m    straight  athletic  mostly anything    socially
# 59945   39  single   m         gay   average              NaN    socially
#
#            drugs                          education     ethnicity  height  \
# 59941      never  graduated from college/university           NaN    62.0
# 59942  sometimes      working on college/university  white, other    72.0
# 59943      never     graduated from masters program         asian    71.0
# 59944      often      working on college/university  asian, black    73.0
# 59945        NaN     graduated from masters program         white    68.0
#
# ...

# %%
df.shape
# Out:
# (59946, 20)

# %%
df.sample(5)
# Out:
#        age  status sex orientation body_type             diet    drinks  \
# 37060   25  single   m    straight       fit  mostly anything  socially
# 42847   31  single   m         gay       fit  mostly anything  socially
# 12647   30  single   m    straight      thin  mostly anything  socially
# 34292   19  single   m    straight  athletic  mostly anything  socially
# 44283   39  single   m    straight   average  mostly anything     often
#
#            drugs                          education                ethnicity  \
# 37060        NaN  graduated from college/university           middle eastern
# 42847      never  graduated from college/university                    white
# 12647      never                                NaN                    asian
# 34292  sometimes                                NaN                      NaN
# 44283      never  graduated from college/university  asian, hispanic / latin
#
#        height  income                             job  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5    diet        35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  location     59946 non-null  object
#  14  offspring    24385 non-null  object
#  15  pets         40025 non-null  object
#  16  religion     39720 non-null  object
#  17  sign         48890 non-null  object
# ...

# %%
df['body_type'].isnull().sum()
# Out:
# 5296

# %%
df[df['body_type'].isnull()]
# Out:
#        age  status sex orientation body_type               diet    drinks  \
# 8       24  single   f    straight       NaN  strictly anything  socially
# 12      24  single   m    straight       NaN                NaN     often
# 70      25  single   f    straight       NaN                NaN    rarely
# 91      29  single   m    straight       NaN                NaN       NaN
# 108     28  single   f    straight       NaN                NaN  socially
# ...    ...     ...  ..         ...       ...                ...       ...
# 59924   25  single   f    straight       NaN                NaN  socially
# 59933   30  single   f    straight       NaN                NaN  socially
# 59939   52  single   m    straight       NaN                NaN  socially
# 59940   31  single   f    straight       NaN                NaN  socially
# 59941   59  single   f    straight       NaN                NaN  socially
#
#        drugs                          education         ethnicity  height  \
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# status             0
# sex                0
# orientation        0
# body_type       5296
#  diet          24395
# drinks          2985
# drugs          14080
# education       6628
# ethnicity       5680
# height             3
# income             0
# job             8198
# location           0
# offspring      35561
# pets           19921
# religion       20226
# sign           11056
# smokes          5512
# speaks            50
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#        age  status sex orientation body_type             diet      drinks  \
# 24262   42  single   m    straight       fit              NaN    socially
# 33404   34  single   f    straight  athletic  mostly anything  not at all
# 33411   34  single   f    straight  athletic  mostly anything  not at all
# 43579   26  single   m    straight  athletic              NaN    socially
#
#        drugs                   education ethnicity  height  income  \
# 24262  never                         NaN     white    71.0      -1
# 33404  never  graduated from high school     white    59.0      -1
# 33411  never  graduated from high school     white    59.0      -1
# 43579  never                         NaN     white    72.0      -1
#
#                                 job                location  \
# 24262  science / tech / engineering  san rafael, california
# 33404     clerical / administrative    martinez, california
# 33411     clerical / administrative    martinez, california
# ...

# %%
df[df.duplicated(keep = False)]
# Out:
#        age  status sex orientation body_type             diet      drinks  \
# 23005   42  single   m    straight       fit              NaN    socially
# 24262   42  single   m    straight       fit              NaN    socially
# 29299   34  single   f    straight  athletic  mostly anything  not at all
# 33404   34  single   f    straight  athletic  mostly anything  not at all
# 33411   34  single   f    straight  athletic  mostly anything  not at all
# 39659   26  single   m    straight  athletic              NaN    socially
# 43579   26  single   m    straight  athletic              NaN    socially
#
#        drugs                   education ethnicity  height  income  \
# 23005  never                         NaN     white    71.0      -1
# 24262  never                         NaN     white    71.0      -1
# 29299  never  graduated from high school     white    59.0      -1
# 33404  never  graduated from high school     white    59.0      -1
# ...

# %%
# 5 numbers summary (numerical columns)

df.describe()
# Out:
#                 age        height          income
# count  59946.000000  59943.000000    59946.000000
# mean      32.340290     68.295281    20033.222534
# std        9.452779      3.994803    97346.192104
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max      110.000000     95.000000  1000000.000000

# %%
df[df['height'] == 1.00000]
# Out:
#        age  status sex orientation body_type  diet      drinks  drugs  \
# 45959   36  single   m    straight       NaN   NaN  very often  never
#
#                                education ethnicity  height  income  \
# 45959  graduated from college/university       NaN     1.0   80000
#
#                                 job             location offspring  \
# 45959  science / tech / engineering  oakland, california       NaN
#
#                           pets                       religion  \
# 45959  likes dogs and has cats  judaism and laughing about it
#
#                                         sign         smokes  \
# 45959  leo and it&rsquo;s fun to think about  when drinking
#
#                                                   speaks
# 45959  english (fluently), c++ (fluently), hebrew (po...

# %%
df[df['income'] == -1]
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 2       38  available   m    straight            thin           anything
# 4       29     single   m    straight        athletic                NaN
# 5       29     single   m    straight         average    mostly anything
# 6       32     single   f    straight             fit  strictly anything
# ...    ...        ...  ..         ...             ...                ...
# 59940   31     single   f    straight             NaN                NaN
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#          drinks      drugs                          education  \
# ...

# %%
df[df['income'] > 1]
# Out:
#        age          status sex orientation     body_type             diet  \
# 1       35          single   m    straight       average     mostly other
# 3       23          single   m    straight          thin       vegetarian
# 11      28  seeing someone   m    straight       average  mostly anything
# 13      30          single   f    straight        skinny  mostly anything
# 14      29          single   f    straight          thin  mostly anything
# ...    ...             ...  ..         ...           ...              ...
# 59917   26          single   m    straight           fit  mostly anything
# 59927   26          single   f    straight  full figured              NaN
# 59930   41          single   m         gay         curvy         anything
# 59934   43          single   f    straight       average         anything
# 59943   42          single   m    straight       average  mostly anything
#
#            drinks      drugs                          education  \
# ...

# %% [markdown]
# **Data Cleaning**

# %%
# Always make sure to create a copy of your pandas dataframe before you start the cleaning process

df1 = df.copy()

# %%
df1.isnull().sum()
# Out:
# age                0
# status             0
# sex                0
# orientation        0
# body_type       5296
#  diet          24395
# drinks          2985
# drugs          14080
# education       6628
# ethnicity       5680
# height             3
# income             0
# job             8198
# location           0
# offspring      35561
# pets           19921
# religion       20226
# sign           11056
# smokes          5512
# speaks            50
# dtype: int64

# %%
df1[df1['body_type'].isnull()]
# Out:
#        age  status sex orientation body_type               diet    drinks  \
# 8       24  single   f    straight       NaN  strictly anything  socially
# 12      24  single   m    straight       NaN                NaN     often
# 70      25  single   f    straight       NaN                NaN    rarely
# 91      29  single   m    straight       NaN                NaN       NaN
# 108     28  single   f    straight       NaN                NaN  socially
# ...    ...     ...  ..         ...       ...                ...       ...
# 59924   25  single   f    straight       NaN                NaN  socially
# 59933   30  single   f    straight       NaN                NaN  socially
# 59939   52  single   m    straight       NaN                NaN  socially
# 59940   31  single   f    straight       NaN                NaN  socially
# 59941   59  single   f    straight       NaN                NaN  socially
#
#        drugs                          education         ethnicity  height  \
# ...

# %%
# replaced all NaN values with 'Blank Data'

df1.fillna('Blank Data',inplace=True)

# %%
# Test

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    59946 non-null  object
#  5    diet        59946 non-null  object
#  6   drinks       59946 non-null  object
#  7   drugs        59946 non-null  object
#  8   education    59946 non-null  object
#  9   ethnicity    59946 non-null  object
#  10  height       59946 non-null  object
#  11  income       59946 non-null  int64
#  12  job          59946 non-null  object
#  13  location     59946 non-null  object
#  14  offspring    59946 non-null  object
#  15  pets         59946 non-null  object
#  16  religion     59946 non-null  object
#  17  sign         59946 non-null  object
# ...

# %%
df1
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# ...

# %%
df1['city'] = df1['location'].str.split(',').str.get(0)
df1['state'] = df1['location'].str.split(',').str.get(1)

# %%
df1.sample(10)
# Out:
#        age  status sex orientation   body_type               diet      drinks  \
# 9479    21  single   m    straight     average    mostly anything  not at all
# 57064   28  single   f    straight  Blank Data         Blank Data    socially
# 43409   38  single   m    straight  overweight    mostly anything      rarely
# 39066   40  single   m    straight    athletic    mostly anything    socially
# 31653   24  single   m    straight     average         Blank Data    socially
# 12690   22  single   m    straight    athletic  strictly anything    socially
# 6742    34  single   m    straight     average    mostly anything    socially
# 58134   48  single   m    straight     average         Blank Data    socially
# 46967   25  single   f    straight  Blank Data         Blank Data    socially
# 14186   32  single   m    straight    athletic    mostly anything    socially
#
#             drugs                          education             ethnicity  \
# ...

# %%
df1.drop(columns = 'location' )
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic         Blank Data
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight      Blank Data         Blank Data
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average         Blank Data
#
#            drinks       drugs                          education  \
# ...

# %%
df1
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic         Blank Data
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight      Blank Data         Blank Data
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average         Blank Data
#
#            drinks       drugs                          education  \
# ...

# %%
df1['income'] = df1['income'].replace(-1,0)

# %%
df1.describe()
# Out:
#                 age          income
# count  59946.000000    59946.000000
# mean      32.340290    20034.030628
# std        9.452779    97346.025793
# min       18.000000        0.000000
# 25%       26.000000        0.000000
# 50%       30.000000        0.000000
# 75%       37.000000        0.000000
# max      110.000000  1000000.000000

# %%
df1
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic         Blank Data
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight      Blank Data         Blank Data
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average         Blank Data
#
#            drinks       drugs                          education  \
# ...

# %% [markdown]
# **Age**

# %%
plt.hist(df1['age'],bins=20,color='plum',histtype='barstacked',edgecolor='black')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
df1['age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# skewness - if value is close to zero then normal distribution , if positive, then positively skewed data

df['age'].skew()
# Out:
# 1.2657731208362886

# %%
plt.boxplot(df1['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f421b1eeb80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f421b32c6d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f421b1ee8e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f421b285070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f421b285b80>],
#  'means': []}

# %%
df1[df1['age']>60]
# Out:
#        age  status sex orientation       body_type               diet  \
# 172     62  single   m    straight             fit           anything
# 233     66  single   f    straight             fit    mostly anything
# 257     63  single   f    straight            thin         Blank Data
# 320     63  single   f         gay  a little extra         Blank Data
# 323     62  single   f    straight            thin           anything
# ...    ...     ...  ..         ...             ...                ...
# 59428   68  single   f    straight    full figured    mostly anything
# 59501   62  single   f    straight           curvy           anything
# 59601   69  single   f    straight        athletic  mostly vegetarian
# 59740   61  single   f    straight        athletic           anything
# 59837   66  single   f    straight           curvy           anything
#
#            drinks       drugs                          education ethnicity  \
# ...

# %% [markdown]
# **Gender**

# %%
df1['sex'].value_counts()
# Out:
# m    35829
# f    24117
# Name: sex, dtype: int64

# %%
df1['sex'].value_counts()
category=['Male','Female']
plt.pie(df1['sex'].value_counts(),labels=category,autopct='%0.1f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb663d09700>,
# ...
#  [Text(-0.33231081024493553, 1.0486036073723735, 'Male'),
#   Text(0.33231071206757834, -1.0486036384855526, 'Female')],
#  [Text(-0.18126044195178298, 0.5719656040212946, '59.8%'),
#   Text(0.18126038840049724, -0.5719656209921195, '40.2%')])

# %% [markdown]
# **Status**

# %%
df1['status'].value_counts()
# Out:
# single            55697
# seeing someone     2064
# available          1865
# married             310
# unknown              10
# Name: status, dtype: int64

# %%
plt.bar(df1['status'].value_counts().keys(),df1['status'].value_counts(),edgecolor='black')
plt.xlabel('Status')
plt.ylabel('Number of users')
plt.xticks(rotation=30)
plt.show()

# %%
group_data=df1.groupby(['status','sex']).size().unstack()
ax=group_data.plot(kind='bar',color=['pink','deepskyblue'],edgecolor='black')
plt.xlabel('status',fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Orientation**

# %%
df1['orientation'].value_counts()
# Out:
# straight    51606
# gay          5573
# bisexual     2767
# Name: orientation, dtype: int64

# %%
plt.bar(df1['orientation'].value_counts().keys(),df1['orientation'].value_counts(),color=['orange','mediumseagreen','fuchsia'],edgecolor='black')
plt.xlabel('Orientation',fontsize=12)
plt.ylabel('Number of users')
plt.show()

# %% [markdown]
# **Body** **Type**

# %%
df1['body_type'].value_counts().plot(kind='bar',color=['#3449eb','#348feb','#4e7cf2','#34abeb','#34a1ed','#4eabf2','#4eabf4'])
plt.xlabel('Body Type',fontsize=12)
# Out:
# Text(0.5, 0, 'Body Type')

# %%
group_data=df1.groupby(['body_type','sex']).size().unstack()
ax=group_data.plot(kind='bar',color=['pink','deepskyblue'],edgecolor='black')
plt.xlabel('Body Type',fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Diet**

# %%
df1[' diet'].value_counts().plot(kind='bar')
plt.xlabel('Diet',fontsize=13)
# Out:
# Text(0.5, 0, 'Diet')

# %% [markdown]
# **Drinks**

# %%
df1['drinks'].value_counts().plot(kind='bar')
plt.xlabel('Drinking Habit',fontsize=13)
# Out:
# Text(0.5, 0, 'Drinking Habit')

# %%
group_data=df1.groupby(['drinks','sex']).size().unstack()
ax=group_data.plot(kind='bar',color=['pink','deepskyblue'],edgecolor='black')
plt.xlabel('Drinking Habit',fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Drug**

# %%
group_data=df1.groupby(['drugs','sex']).size().unstack()
ax=group_data.plot(kind='barh',color=['pink','deepskyblue'],edgecolor='black')
plt.ylabel('Drugs Habit',fontsize=13)
plt.show()

# %% [markdown]
# **Job**

# %%
df1['job'].value_counts().plot(kind='bar')
plt.xlabel('Job',fontsize=13)
# Out:
# Text(0.5, 0, 'Job')

# %% [markdown]
# **State**

# %%
df1['state'].value_counts().head(10)
# Out:
#  california              59855
#  new york                   17
#  illinois                    8
#  massachusetts               5
#  texas                       4
#  oregon                      4
#  michigan                    4
#  arizona                     3
#  florida                     3
#  district of columbia        2
# Name: state, dtype: int64

# %% [markdown]
# **Smokes**

# %%
df1['smokes'].value_counts()
# Out:
# no                43896
# Blank Data         5512
# sometimes          3787
# when drinking      3040
# yes                2231
# trying to quit     1480
# Name: smokes, dtype: int64

# %%
df1['smokes'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='smokes'>

# %% [markdown]
# **Religion**

# %%
and1=df1['religion'].str.split('and').str.get(0)

# %%
religion1=and1.str.split('but').str.get(0)

# %%
df1['religion1']=religion1

# %%
df1['religion1'].value_counts().plot(kind='bar',xlabel='Religion')
# Out:
# <Axes: xlabel='Religion'>

# %% [markdown]
# **Sign**

# %%
and1=df1['sign'].str.split('and').str.get(0)
sign1=and1.str.split('but').str.get(0)

# %%
sign1
# Out:
# 0              gemini
# 1              cancer
# 2             pisces
# 3              pisces
# 4            aquarius
#              ...
# 59941         cancer
# 59942            leo
# 59943    sagittarius
# 59944            leo
# 59945         gemini
# Name: sign, Length: 59946, dtype: object

# %%
df1['sign1']=sign1

# %%
df1['sign1']
# Out:
# 0              gemini
# 1              cancer
# 2             pisces
# 3              pisces
# 4            aquarius
#              ...
# 59941         cancer
# 59942            leo
# 59943    sagittarius
# 59944            leo
# 59945         gemini
# Name: sign1, Length: 59946, dtype: object
